# %%
import pandas as pd
data=pd.read_excel('EJIS_all_articles_v1.xlsx')
data.head()
# Out:
#                                        Journal_Title  \
# 0  European Journal of Information Systems, Volum...
# 1  European Journal of Information Systems, Volum...
# 2  European Journal of Information Systems, Volum...
# 3  European Journal of Information Systems, Volum...
# 4  European Journal of Information Systems, Volum...
#
#                                                  URL  \
# 0  https://www.tandfonline.com/doi/full/10.1080/0...
# 1  https://www.tandfonline.com/doi/full/10.1080/0...
# 2  https://www.tandfonline.com/doi/full/10.1080/0...
# 3  https://www.tandfonline.com/doi/full/10.1080/0...
# 4  https://www.tandfonline.com/doi/full/10.1080/0...
#
#                                        Article_Title Volume_Issue  \
# 0  Security and privacy risks in drone-based last...      Issue 5
# 1  Security and privacy risks in drone-based last...      Issue 5
# 2  Security by envelopment Ã¢â‚¬â€œ a novel appro...      Issue 5
# 3  Security by envelopment Ã¢â‚¬â€œ a novel appro...      Issue 5
# 4  Security by envelopment Ã¢â‚¬â€œ a novel appro...      Issue 5
#
#                   Month_Year  \
# 0  Volume 33, 2024 - Issue 5
# 1  Volume 33, 2024 - Issue 5
# 2  Volume 33, 2024 - Issue 5
# 3  Volume 33, 2024 - Issue 5
# 4  Volume 33, 2024 - Issue 5
#
#                                             Abstract  \
# 0  The consideration of drones for last mile deli...
# 1  The consideration of drones for last mile deli...
# 2  Organisationsâ€™ increasing adoption of lightw...
# 3  Organisationsâ€™ increasing adoption of lightw...
# 4  Organisationsâ€™ increasing adoption of lightw...
#
#                                             Keywords          Author_name  \
# 0  ['Drone', 'identifier', 'last mile delivery', ...             Yu-Ju Tu
# 1  ['Drone', 'identifier', 'last mile delivery', ...     Selwyn Piramuthu
# 2  ['Organisational data security', 'robotic proc...  Aleksandre Asatiani
# 3  ['Organisational data security', 'robotic proc...    Tuuli Hakkarainen
# 4  ['Organisational data security', 'robotic proc...          Kimmo Paaso
#
#                                           Author_url  \
# 0     https://www.tandfonline.com/author/Tu%2C+Yu-Ju
# 1  https://www.tandfonline.com/author/Piramuthu%2...
# 2  https://www.tandfonline.com/author/Asatiani%2C...
# 3  https://www.tandfonline.com/author/Hakkarainen...
# 4  https://www.tandfonline.com/author/Paaso%2C+Kimmo
#
#                                       Author_Address  \
# 0  a Management Information Systems, National Che...
# 1  b Information Systems and Operations Managemen...
# 2  a Swedish Center for Digital Innovation, Unive...
# 3  b Work, Organisation and Management Group, Uni...
# 4  HR Reporting and Business Intelligence, Wärtsi...
#
#                     Author_email
# 0                            NaN
# 1                 selwyn@ufl.edu
# 2  aleksandre.asatiani@ait.gu.se
# 3                            NaN
# 4                            NaN

# %%
#column types and null values
print(data.info())
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2561 entries, 0 to 2560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Journal_Title   2561 non-null   object
#  1   URL             2561 non-null   object
#  2   Article_Title   2561 non-null   object
#  3   Volume_Issue    2561 non-null   object
#  4   Month_Year      2561 non-null   object
#  5   Abstract        2472 non-null   object
#  6   Keywords        2561 non-null   object
#  7   Author_name     2561 non-null   object
#  8   Author_url      1931 non-null   object
#  9   Author_Address  2557 non-null   object
#  10  Author_email    629 non-null    object
# dtypes: object(11)
# memory usage: 220.2+ KB
# None
# Journal_Title        0
# URL                  0
# Article_Title        0
# Volume_Issue         0
# Month_Year           0
# Abstract            89
# Keywords             0
# Author_name          0
# Author_url         630
# Author_Address       4
# Author_email      1932
# dtype: int64

# %%
#drop rows with missing Author_Address
df = data.dropna(subset=['Author_Address'])

# %%
df.isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2557 entries, 0 to 2560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Journal_Title   2557 non-null   object
#  1   URL             2557 non-null   object
#  2   Article_Title   2557 non-null   object
#  3   Volume_Issue    2557 non-null   object
#  4   Month_Year      2557 non-null   object
#  5   Abstract        2468 non-null   object
#  6   Keywords        2557 non-null   object
#  7   Author_name     2557 non-null   object
#  8   Author_url      1927 non-null   object
#  9   Author_Address  2557 non-null   object
#  10  Author_email    629 non-null    object
# dtypes: object(11)
# memory usage: 239.7+ KB

# %%
#fill remaining null values with 'NULL'
df = data.fillna('NULL')

# %%
print(data.describe())
# Out:
#                                             Journal_Title  \
# count                                                2561
# unique                                                133
# top     European Journal of Information Systems, Volum...
# freq                                                   46
#
#                                                       URL Article_Title  \
# count                                                2561          2561
# unique                                               1027          1019
# top     https://www.tandfonline.com/doi/full/10.1057/e...     Editorial
# freq                                                   10            12
#
#        Volume_Issue                                         Month_Year  \
# count          2561                                               2561
# unique           18                                                133
# top         Issue 3  Volume 16, 2007 - Issue 4: Including a Special...
# freq            447                                                 46
#
#                                                  Abstract Keywords  \
# count                                                2472     2561
# unique                                                862      712
# top     Information Systems Research (â€œWirtschaftsin...       []
# freq                                                   10      215
#
#         Author_name                                        Author_url  \
# count          2561                                              1931
# unique         1901                                              1444
# top     Frantz Rowe  https://www.tandfonline.com/author/Paul%2C+Ray+J
# freq             14                                                15
#
#                                            Author_Address  \
# count                                                2557
# unique                                               2354
# top     Department of Information Systems and Computin...
# freq                                                   10
#
#                   Author_email
# count                      629
# unique                     548
# top     m.myers@auckland.ac.nz
# freq                         5

# %%
#check for duplicates incuding first occurrence
df[df.duplicated(keep=False)]
# Out:
#                                           Journal_Title  \
# 2442  European Journal of Information Systems, Volum...
# 2443  European Journal of Information Systems, Volum...
# 2444  European Journal of Information Systems, Volum...
# 2445  European Journal of Information Systems, Volum...
# 2446  European Journal of Information Systems, Volum...
# 2447  European Journal of Information Systems, Volum...
# 2448  European Journal of Information Systems, Volum...
# 2449  European Journal of Information Systems, Volum...
# 2450  European Journal of Information Systems, Volum...
# 2451  European Journal of Information Systems, Volum...
# 2452  European Journal of Information Systems, Volum...
# 2453  European Journal of Information Systems, Volum...
# 2454  European Journal of Information Systems, Volum...
# 2455  European Journal of Information Systems, Volum...
# 2456  European Journal of Information Systems, Volum...
# 2457  European Journal of Information Systems, Volum...
# 2458  European Journal of Information Systems, Volum...
# 2459  European Journal of Information Systems, Volum...
#
#                                                     URL  \
# 2442  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2443  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2444  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2445  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2446  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2447  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2448  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2449  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2450  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2451  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2452  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2453  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2454  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2455  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2456  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2457  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2458  https://www.tandfonline.com/doi/abs/10.1057/pa...
# 2459  https://www.tandfonline.com/doi/abs/10.1057/pa...
#
#                                           Article_Title Volume_Issue  \
# 2442  Information systems evaluation: past, present ...      Issue 4
# 2443  Information systems evaluation: past, present ...      Issue 4
# 2444  Understanding IS evaluation as a complex socia...      Issue 4
# 2445  Understanding IS evaluation as a complex socia...      Issue 4
# 2446  A framework for the ex-ante evaluation of ERP ...      Issue 4
# 2447  ERP software implementation: an integrative fr...      Issue 4
# 2448  ERP software implementation: an integrative fr...      Issue 4
# 2449  ERP software implementation: an integrative fr...      Issue 4
# 2450  The impact of information technology on financ...      Issue 4
# 2451  Information systems evaluation: past, present ...      Issue 4
# 2452  Information systems evaluation: past, present ...      Issue 4
# 2453  Understanding IS evaluation as a complex socia...      Issue 4
# 2454  Understanding IS evaluation as a complex socia...      Issue 4
# 2455  A framework for the ex-ante evaluation of ERP ...      Issue 4
# 2456  ERP software implementation: an integrative fr...      Issue 4
# 2457  ERP software implementation: an integrative fr...      Issue 4
# 2458  ERP software implementation: an integrative fr...      Issue 4
# 2459  The impact of information technology on financ...      Issue 4
#
#                      Month_Year  \
# 2442  Volume 10, 2001 - Issue 4
# 2443  Volume 10, 2001 - Issue 4
# 2444  Volume 10, 2001 - Issue 4
# 2445  Volume 10, 2001 - Issue 4
# 2446  Volume 10, 2001 - Issue 4
# 2447  Volume 10, 2001 - Issue 4
# 2448  Volume 10, 2001 - Issue 4
# 2449  Volume 10, 2001 - Issue 4
# 2450  Volume 10, 2001 - Issue 4
# 2451  Volume 10, 2001 - Issue 4
# 2452  Volume 10, 2001 - Issue 4
# 2453  Volume 10, 2001 - Issue 4
# 2454  Volume 10, 2001 - Issue 4
# 2455  Volume 10, 2001 - Issue 4
# 2456  Volume 10, 2001 - Issue 4
# 2457  Volume 10, 2001 - Issue 4
# 2458  Volume 10, 2001 - Issue 4
# 2459  Volume 10, 2001 - Issue 4
#
#                                                Abstract Keywords  \
# 2442                                                NaN       []
# 2443                                                NaN       []
# 2444  The increasing concern from both IS practition...       []
# 2445  The increasing concern from both IS practition...       []
# 2446  It has been widely reported that a large numbe...       []
# 2447  ERP implementation is a socio-technical challe...       []
# 2448  ERP implementation is a socio-technical challe...       []
# 2449  ERP implementation is a socio-technical challe...       []
# 2450  Information technology (IT) may not automatica...       []
# 2451                                                NaN       []
# 2452                                                NaN       []
# 2453  The increasing concern from both IS practition...       []
# 2454  The increasing concern from both IS practition...       []
# 2455  It has been widely reported that a large numbe...       []
# 2456  ERP implementation is a socio-technical challe...       []
# 2457  ERP implementation is a socio-technical challe...       []
# 2458  ERP implementation is a socio-technical challe...       []
# 2459  Information technology (IT) may not automatica...       []
#
#         Author_name Author_url  \
# 2442        Z Irani        NaN
# 2443     P E D Love        NaN
# 2444        S Jones        NaN
# 2445       J Hughes        NaN
# 2446   C J Stefanou        NaN
# 2447  A Al-Mudimigh        NaN
# 2448        M Zairi        NaN
# 2449   M Al-Mashari        NaN
# 2450         N Shin        NaN
# 2451        Z Irani        NaN
# 2452     P E D Love        NaN
# 2453        S Jones        NaN
# 2454       J Hughes        NaN
# 2455   C J Stefanou        NaN
# 2456  A Al-Mudimigh        NaN
# 2457        M Zairi        NaN
# 2458   M Al-Mashari        NaN
# 2459         N Shin        NaN
#
#                                          Author_Address Author_email
# 2442  Information Systems Evaluation and Integration...          NaN
# 2443  School of Management Information Systems, Edit...          NaN
# 2444  Conwy County Borough Council, BodlondebConwyWa...          NaN
# 2445  Information Systems Institute, University of S...          NaN
# 2446  Technological Educational Institution (TEI) of...          NaN
# 2447  ECTQM, University of BradfordBradfordWest York...          NaN
# 2448  ECTQM, University of BradfordBradfordWest York...          NaN
# 2449  Department of Information SystemsCollege of Co...          NaN
# 2450  School of Computer Science and Information Sys...          NaN
# 2451  Information Systems Evaluation and Integration...          NaN
# 2452  School of Management Information Systems, Edit...          NaN
# 2453  Conwy County Borough Council, BodlondebConwyWa...          NaN
# 2454  Information Systems Institute, University of S...          NaN
# 2455  Technological Educational Institution (TEI) of...          NaN
# 2456  ECTQM, University of BradfordBradfordWest York...          NaN
# 2457  ECTQM, University of BradfordBradfordWest York...          NaN
# 2458  Department of Information SystemsCollege of Co...          NaN
# 2459  School of Computer Science and Information Sys...          NaN

# %%
#drop duplicates, keeping first occurrence
df.drop_duplicates(inplace=True)
# Out:
# /var/folders/pk/rsrc4d3x4vdgqzfqp8r7lw080000gn/T/ipykernel_52179/3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#check for empty strings
df.columns[(df==" ").any()]
# Out:
# Index([], dtype='object')

# %%
df.to_excel('EJIS_all_articles_cleaned_v1.xlsx', index=False)

# %%
import pandas as pd
import mysql.connector
import json

# Connect to MySQL
#Used the DSS_new for date matching
db = mysql.connector.connect(
        host=  "127.0.0.1",
        user= "root",
        password="Nanna&143",
        database="journals",
        auth_plugin='mysql_native_password')
    
cursor = db.cursor()
# Insert data into MySQL
for index, row in df.iterrows():
    standard_name=row["Standardized_Name"] if row['Standardized_Name'] else None
    # keywords = json.dumps(row['Keywords']) if row['Keywords'] else None  # Handle JSON
    # url=row["URL"] if row['URL'] else None
    # journal_title=row["Journal_Title"] if row['Journal_Title'] else None
    # volume_issue=row["Volume_Issue"] if row['Volume_Issue'] else None
    # month_year=row["Month_Year"] if row['Month_Year'] else None
    # abstract=row["Abstract"] if row['Abstract'] else None
    author_name=row["Author_Name"] if row['Author_Name'] else None
    # author_email=row["Author_Email"] if row['Author_Email'] else None
    # author_address=row["Author_Address"] if row['Author_Address'] else None
    

    try:
        sql = """
        Update Journal_Articles
        set Standardized_Name=%s
        where author_name=%s;
        """
        values = (
            standard_name,author_name
        )
        
        cursor.execute(sql, values)
    except Exception as e:
        print(f"Error inserting data: {e}{row["URL"]}")
        break
# Commit & close connection
db.commit()
cursor.close()
db.close()

print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %%
#For the decision support systems titles
import pandas as pd
import mysql.connector
import json

#connect to mysql
db=mysql.connector.connect(
    host="127.0.0.1",
    user='root',
    password='Nanna&143',
    database='journals',
    auth_plugin='mysql_native_password'
)
cursor=db.cursor()
for index, row in df.iterrows():
    title = row["Title"] if row["Title"] else None
    url = row["URL"] if row["URL"] else None
    vol_year=row["Vol Issue Year"] if row["Vol Issue Year"] else None

    try:
        sql = """
        INSERT INTO DecisionSupportSystems
        (Title, URL, vol_issue_year)
        VALUES (%s, %s, %s)
        """
        values = (title, url, vol_year)
        cursor.execute(sql, values)
    except Exception as e:
        print(f"Error inserting data: {e} {row['Title']}")
        break

db.commit()
cursor.close()
db.close()

# %%
import mysql.connector
import pandas as pd

db = mysql.connector.connect(
        host=  "127.0.0.1",
        user= "root",
        password="Nanna&143",
        database="journals",
        auth_plugin='mysql_native_password')

# Define the SQL query
query = "SELECT * FROM Journal_Articles"

# Read data into a Pandas DataFrame
df = pd.read_sql(query, db)

# Export DataFrame to Excel
df.to_excel("Journal_Articles_new.xlsx", index=False, engine="openpyxl")

# Close the database connection
db.close()

print("Data exported successfully to Journal_Articles.xlsx")
# Out:
# /var/folders/pk/rsrc4d3x4vdgqzfqp8r7lw080000gn/T/ipykernel_99855/2316557836.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, db)
# Data exported successfully to Journal_Articles.xlsx
