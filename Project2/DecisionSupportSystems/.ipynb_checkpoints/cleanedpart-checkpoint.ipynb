# %%
import pandas as pd
data=pd.read_csv('DSS_cleaned.csv')
data.head()
# Out:
#                                                  URL  \
# 0  https://www.sciencedirect.com/science/article/...
# 1  https://www.sciencedirect.com/science/article/...
# 2  https://www.sciencedirect.com/science/article/...
# 3  https://www.sciencedirect.com/science/article/...
# 4  https://www.sciencedirect.com/science/article/...
#
#               Journal_Title Volume_Issue      Month_Year  \
# 0  Decision Support Systems   Volume 187   December 2024
# 1  Decision Support Systems   Volume 187   December 2024
# 2  Decision Support Systems   Volume 187   December 2024
# 3  Decision Support Systems   Volume 187   December 2024
# 4  Decision Support Systems   Volume 187   December 2024
#
#                                             Abstract  \
# 0  Online social networks have greatly facilitate...
# 1  Online social networks have greatly facilitate...
# 2  Online social networks have greatly facilitate...
# 3  Online social networks have greatly facilitate...
# 4  Online social networks have greatly facilitate...
#
#                                             Keywords     Author_name  \
# 0  ['Information diffusion', 'Epidemic threshold'...        Saike He
# 1  ['Information diffusion', 'Epidemic threshold'...  Weiguang Zhang
# 2  ['Information diffusion', 'Epidemic threshold'...         Jun Luo
# 3  ['Information diffusion', 'Epidemic threshold'...    Peijie Zhang
# 4  ['Information diffusion', 'Epidemic threshold'...       Kang Zhao
#
#                  Author_email  \
# 0           saike.he@ia.ac.cn
# 1  zhangweiguang2022@ia.ac.cn
# 2          junluo_bit@163.com
# 3       peijie.zhang@ia.ac.cn
# 4         kang-zhao@uiowa.edu
#
#                                       Author_Address  \
# 0  State Key Laboratory of Multimodal Artificial ...
# 1  State Key Laboratory of Multimodal Artificial ...
# 2  State Key Laboratory of Multimodal Artificial ...
# 3  State Key Laboratory of Multimodal Artificial ...
# 4  Department of Business Analytics, Tippie Colle...
#
#              Author_University  \
# 0  Chinese Academy of Sciences
# 1  Chinese Academy of Sciences
# 2  Chinese Academy of Sciences
# 3  Chinese Academy of Sciences
# 4       The University of Iowa
#
#                                    Author_department Author_State  \
# 0                            Institute of Automation      Beijing
# 1                            Institute of Automation      Beijing
# 2                            Institute of Automation      Beijing
# 3  State Key Laboratory of Multimodal Artificial ...      Beijing
# 4  Department of Business Analytics, Tippie Colle...         Iowa
#
#   Author_Country Author_pincode
# 0          China         100190
# 1          China         100190
# 2          China         100190
# 3          China         100190
# 4  United States          52242

# %%
print(data.info())
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10740 entries, 0 to 10739
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   URL                10740 non-null  object
#  1   Journal_Title      10740 non-null  object
#  2   Volume_Issue       10740 non-null  object
#  3   Month_Year         10740 non-null  object
#  4   Abstract           10695 non-null  object
#  5   Keywords           10740 non-null  object
#  6   Author_name        10686 non-null  object
#  7   Author_email       6996 non-null   object
#  8   Author_Address     10675 non-null  object
#  9   Author_University  10528 non-null  object
#  10  Author_department  8864 non-null   object
#  11  Author_State       10310 non-null  object
#  12  Author_Country     10675 non-null  object
#  13  Author_pincode     6770 non-null   object
# dtypes: object(14)
# memory usage: 1.1+ MB
# None
# URL                     0
# Journal_Title           0
# Volume_Issue            0
# Month_Year              0
# Abstract               45
# Keywords                0
# Author_name            54
# Author_email         3744
# Author_Address         65
# Author_University     212
# Author_department    1876
# Author_State          430
# Author_Country         65
# Author_pincode       3970
# dtype: int64

# %%
print(data.describe())
# Out:
#                                                       URL  \
# count                                               10740
# unique                                               3790
# top     https://www.sciencedirect.com/science/article/...
# freq                                                   13
#
#                    Journal_Title        Volume_Issue Month_Year  \
# count                      10740               10740      10740
# unique                         1                 345        141
# top     Decision Support Systems  Volume 54, Issue 1    Issue 1
# freq                       10740                 210       1737
#
#                                                  Abstract Keywords  \
# count                                               10695    10740
# unique                                               3228      133
# top     Web 2.0 has enabled and fostered Internet user...       []
# freq                                                 1128    10293
#
#           Author_name    Author_email  \
# count           10686            6996
# unique           7417            5366
# top     Hsinchun Chen  selwyn@ufl.edu
# freq               44              28
#
#                                            Author_Address  \
# count                                               10675
# unique                                               6634
# top     School of Management, Hefei University of Tech...
# freq                                                   23
#
#                    Author_University     Author_department Author_State  \
# count                          10528                  8864        10310
# unique                          2089                  2459          535
# top     City University of Hong Kong  School of Management    Hong Kong
# freq                             166                   357          419
#
#        Author_Country Author_pincode
# count           10675           6770
# unique             93           1828
# top               USA          85721
# freq             2101            141

# %%
duplicates = data[data.duplicated(keep=False)]
df=data.drop_duplicates()
print(df)
# df=data.drop_duplicates(inplace=True)
# df
# Out:
#                                                      URL  \
# 0      https://www.sciencedirect.com/science/article/...
# 1      https://www.sciencedirect.com/science/article/...
# 2      https://www.sciencedirect.com/science/article/...
# 3      https://www.sciencedirect.com/science/article/...
# 4      https://www.sciencedirect.com/science/article/...
# ...                                                  ...
# 10735  https://www.sciencedirect.com/science/article/...
# 10736  https://www.sciencedirect.com/science/article/...
# 10737  https://www.sciencedirect.com/science/article/...
# 10738  https://www.sciencedirect.com/science/article/...
# 10739  https://www.sciencedirect.com/science/article/...
#
#                   Journal_Title       Volume_Issue      Month_Year  \
# 0      Decision Support Systems         Volume 187   December 2024
# 1      Decision Support Systems         Volume 187   December 2024
# 2      Decision Support Systems         Volume 187   December 2024
# 3      Decision Support Systems         Volume 187   December 2024
# 4      Decision Support Systems         Volume 187   December 2024
# ...                         ...                ...             ...
# 10735  Decision Support Systems  Volume 2, Issue 1         Issue 1
# 10736  Decision Support Systems  Volume 2, Issue 1         Issue 1
# 10737  Decision Support Systems  Volume 2, Issue 1         Issue 1
# 10738  Decision Support Systems  Volume 2, Issue 1         Issue 1
# 10739  Decision Support Systems  Volume 2, Issue 1         Issue 1
#
#                                                 Abstract  \
# 0      Online social networks have greatly facilitate...
# 1      Online social networks have greatly facilitate...
# 2      Online social networks have greatly facilitate...
# 3      Online social networks have greatly facilitate...
# 4      Online social networks have greatly facilitate...
# ...                                                  ...
# 10735  An important purpose of the research being don...
# 10736  The concept of model management as a logical e...
# 10737  Changes in computer technology have provided d...
# 10738  Changes in computer technology have provided d...
# 10739  Changes in computer technology have provided d...
#
#                                                 Keywords        Author_name  \
# 0      ['Information diffusion', 'Epidemic threshold'...           Saike He
# 1      ['Information diffusion', 'Epidemic threshold'...     Weiguang Zhang
# 2      ['Information diffusion', 'Epidemic threshold'...            Jun Luo
# 3      ['Information diffusion', 'Epidemic threshold'...       Peijie Zhang
# 4      ['Information diffusion', 'Epidemic threshold'...          Kang Zhao
# ...                                                  ...                ...
# 10735                                                 []  Robert W Blanning
# 10736                                                 []      Daniel R Dolk
# 10737                                                 []  Lynda M Applegate
# 10738                                                 []   Benn R Konsynski
# 10739                                                 []    Jay F Nunamaker
#
#                      Author_email  \
# 0               saike.he@ia.ac.cn
# 1      zhangweiguang2022@ia.ac.cn
# 2              junluo_bit@163.com
# 3           peijie.zhang@ia.ac.cn
# 4             kang-zhao@uiowa.edu
# ...                           ...
# 10735                         NaN
# 10736                         NaN
# 10737                         NaN
# 10738                         NaN
# 10739                         NaN
#
#                                           Author_Address  \
# 0      State Key Laboratory of Multimodal Artificial ...
# 1      State Key Laboratory of Multimodal Artificial ...
# 2      State Key Laboratory of Multimodal Artificial ...
# 3      State Key Laboratory of Multimodal Artificial ...
# 4      Department of Business Analytics, Tippie Colle...
# ...                                                  ...
# 10735  Owen Graduate School of Management, Vanderbilt...
# 10736  Dept. of Administrative Sciences, Naval Postgr...
# 10737  Department of Management Information Systems, ...
# 10738  Department of Management Information Systems, ...
# 10739  Department of Management Information Systems, ...
#
#                  Author_University  \
# 0      Chinese Academy of Sciences
# 1      Chinese Academy of Sciences
# 2      Chinese Academy of Sciences
# 3      Chinese Academy of Sciences
# 4           The University of Iowa
# ...                            ...
# 10735        Vanderbilt University
# 10736    Naval Postgraduate School
# 10737        University of Arizona
# 10738        University of Arizona
# 10739        University of Arizona
#
#                                        Author_department Author_State  \
# 0                                Institute of Automation      Beijing
# 1                                Institute of Automation      Beijing
# 2                                Institute of Automation      Beijing
# 3      State Key Laboratory of Multimodal Artificial ...      Beijing
# 4      Department of Business Analytics, Tippie Colle...         Iowa
# ...                                                  ...          ...
# 10735                 Owen Graduate School of Management    Tennessee
# 10736                   Dept. of Administrative Sciences   California
# 10737       Department of Management Information Systems      Arizona
# 10738       Department of Management Information Systems      Arizona
# 10739       Department of Management Information Systems      Arizona
#
#       Author_Country Author_pincode
# 0              China         100190
# 1              China         100190
# 2              China         100190
# 3              China         100190
# 4      United States          52242
# ...              ...            ...
# 10735  United States          37203
# 10736  United States          93943
# 10737            USA          85721
# 10738            USA          85721
# 10739            USA          85721
#
# [10706 rows x 14 columns]

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
data.to_excel('result.xlsx',index=False)

# %%
pip install pandas sqlalchemy mysql-connector-python
# Out:
# Requirement already satisfied: pandas in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: sqlalchemy in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (2.0.30)
# Requirement already satisfied: mysql-connector-python in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (9.1.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas mysql-connector-python
# Out:
# Requirement already satisfied: pandas in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: mysql-connector-python in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (9.1.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\h664k297\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import mysql.connector

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="journals"
)
cursor = conn.cursor()

# Load Excel file
df = pd.read_csv('DSS_cleaned.csv') 



# Insert data into MySQL
for index, row in df.iterrows[2:]():
    sql = """
    INSERT INTO Journal_Articles 
    (URL, Journal_Title, Volume_Issue, Month_Year, Abstract, Keywords, 
     Author_Name, Author_Email, Author_University, Author_Department, 
     Author_State, Author_Country, Author_Pincode) 
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    values = (
        row["URL"], row["Journal_Title"], row["Volume_Issue"], row["Month_Year"], 
        row["Abstract"], row["Keywords"], row["Author_Name"], row["Author_Email"],
        row["Author_University"], row["Author_Department"], row["Author_State"], 
        row["Author_Country"], row["Author_Pincode"]
    )
    
    cursor.execute(sql, values)

# Commit & close connection
conn.commit()
cursor.close()
conn.close()

print("Data inserted successfully!")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
